# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhimamathur/Codes/blob/main/first_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict = {'name': 'Alice', 'age': 30}

for key, value in my_dict.items():
    print(f"{key}: {value}")
# Out:
# name: Alice
# age: 30

# %%
n = 6
fact = 1

for i in range(1, n + 1):
    fact *= i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720

# %%
student = { 'name':'riddhima', 'age':'18','roll':'2704' }
print(student["name"])
print(student["roll"])
print(student["age"])
# Out:
# riddhima
# 2704
# 18
